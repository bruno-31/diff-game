# %%
ls *.npy
# Out:
# con_dist.npy     nn_dist_sgd.npy    plot_ema_kl_3.npy  plot_sga_kl.npy
# kldist.npy       nndist_sgd.npy     plot_ema_kl.npy    plot_sga_nn.npy
# kl_dist_sgd.npy  plot_con_kl.npy    plot_ema_nn_2.npy  sga_dist.npy
# kldist_sgd.npy   plot_con_nn.npy    plot_ema_nn_3.npy  sgd_dist.npy
# nndist.npy       plot_ema_kl_2.npy  plot_ema_nn.npy    testouille.npy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.load('plot_ema_kl_3.npy')
y=np.load('plot_sga_kl.npy')
z=np.load('plot_con_kl.npy')
w=np.load('plot_sgd_kl.npy')

# %%
t=np.linspace(0,20000,len(x))
plt.semilogy(t,w)
plt.semilogy(t,y)
plt.semilogy(t,z)
plt.semilogy(t,x)

plt.xlabel('gradient iters')
plt.ylabel('KL divergence')
plt.legend(['sgd','sga', 'concensus','ema e=0.999'])
