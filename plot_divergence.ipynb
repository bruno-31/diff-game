# %%
ls *.npy
# Out:
# plot_con_kl.npy    plot_ema_nn_4.npy          plot_sga_with_alignment_kl.npy
# plot_con_nn.npy    plot_sga_alignment_kl.npy  plot_sga_with_alignment_nn.npy
# plot_ema_kl_3.npy  plot_sga_alignment_nn.npy  plot_sgd_kl.npy
# plot_ema_kl_4.npy  plot_sga_kl.npy            plot_sgd_nn.npy
# plot_ema_nn_3.npy  plot_sga_nn.npy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.load('plot_ema_nn_3.npy')
y=np.load('plot_sga_nn.npy')
z=np.load('plot_con_nn.npy')
w=np.load('plot_sgd_nn.npy')

# %%
t=np.linspace(0,20000,len(x))
plt.semilogy(t,w)
plt.semilogy(t,y)
plt.semilogy(t,z)
plt.semilogy(t,x)

plt.xlabel('gradient iters')
plt.ylabel('NN analysis')
plt.legend(['sgd','sga', 'concensus','ema e=0.999'])
